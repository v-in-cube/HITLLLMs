# %%
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None
pd.options.display.max_rows = 999

# %%
df = pd.read_csv("expert_feedback_combined_new_llms.csv")

# %%
df[df["reaction_hash"]=="2dcdfaba0b39f9811e955fc9641ba0a3dda980699559ea7f1c9bb06355596713"]
# Out:
#                                      source_file  \
# 86     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 87     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 88     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 296    f17aff6e-1f78-4f8d-aeaf-41d0e7e60838.json
# 354    bcf28a27-67e7-4386-a5bb-3bde92bc6e8f.json
# 603    205a5ab7-cc28-4142-94ea-5c1417f13ba9.json
# 604    205a5ab7-cc28-4142-94ea-5c1417f13ba9.json
# 707    f04e3884-b923-4724-bdd6-047cf9882afa.json
# 866    1cef1c2a-8777-49c3-8ab5-c8db4b1fb5bc.json
# 1746                             Claude Opus 4.8
# 1753                             Claude Opus 4.8
# 1760                             Claude Opus 4.8
# 1767                             Claude Opus 4.8
# 2555                             Claude Opus 4.8
# 2562                             Claude Opus 4.8
# 2569                             Claude Opus 4.8
# 2576                             Claude Opus 4.8
# 3361                             Claude Opus 4.8
# ...

# %%
df[df["reaction_hash"]=="c5b4c7ead91867b307b10848eb62979938baa8081df3d9634ec30196322801b0"]
# Out:
#                                      source_file  \
# 34     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 182    0d1edcde-bcac-4c85-a373-5f132cc02c7e.json
# 183    0d1edcde-bcac-4c85-a373-5f132cc02c7e.json
# 478    231259c3-8b13-4993-9b47-2a41ef2eea0b.json
# 731    f04e3884-b923-4724-bdd6-047cf9882afa.json
# 732    f04e3884-b923-4724-bdd6-047cf9882afa.json
# 839    1cef1c2a-8777-49c3-8ab5-c8db4b1fb5bc.json
# 954    9682ddec-bb3b-4f25-a8b4-55739c844027.json
# 1678                             Claude Opus 4.8
# 1681                             Claude Opus 4.8
# 1684                             Claude Opus 4.8
# 1687                             Claude Opus 4.8
# 2487                             Claude Opus 4.8
# 2490                             Claude Opus 4.8
# 2493                             Claude Opus 4.8
# 2496                             Claude Opus 4.8
# 3293                             Claude Opus 4.8
# 3296                             Claude Opus 4.8
# ...

# %%
df[df["reaction_hash"]=="f3c6eb5fe1a68e5f8755c045ce859f22a00e8f6dac1a7a36f6603e8d300af6b3"]
# Out:
#                                      source_file  \
# 76     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 77     c7c32d61-fdff-4ec6-a7ea-0428802a2db4.json
# 956    9682ddec-bb3b-4f25-a8b4-55739c844027.json
# 957    9682ddec-bb3b-4f25-a8b4-55739c844027.json
# 1058   f34a81f8-fc85-4045-aed8-676c4af481b6.json
# 1059   f34a81f8-fc85-4045-aed8-676c4af481b6.json
# 1111   02469231-98fb-468d-ae67-1e06d5b9279b.json
# 1966                             Claude Opus 4.8
# 1968                             Claude Opus 4.8
# 1970                             Claude Opus 4.8
# 1972                             Claude Opus 4.8
# 2773                             Claude Opus 4.8
# 2775                             Claude Opus 4.8
# 2777                             Claude Opus 4.8
# 2779                             Claude Opus 4.8
# 3581                             Claude Opus 4.8
# 3583                             Claude Opus 4.8
# 3585                             Claude Opus 4.8
# ...
